# %%
# question 4

# creating empty list
data=[]
def enter_data():
   x=input("enter any data :")
# to confirm that something was inputed
   if x.isalpha and x!='':
        return x
# adding input to data[]
def add_data(val,lst):
   lst.append(val)
   return lst
# displaying list
def display(lst):
   print("Showing products",lst)
   addAnotherData()
    
# searching throught products
def search():
    search_data = input('Enter item to search : ')
    print('searching.......')
    mode = data.count(search_data)
    if search_data in data:
        print('your input "',search_data,'" was found',mode,'time(s)')
    else:
        print('sorry your input "',search_data,'" was not found')
    display(m)
# adding infinite data
def addAnotherData():
    x=input("Add another Y, exit N, search S or display-products D")
    if x=="Y":
      print("Adding another ....")
      x = enter_data()
      m = add_data(x,data)
      display(m)
        
    if x=="s" and x.isalpha():
        search()
        
    if x=="d":
        print(data)
        confirm()
        
    elif x=="n":
       print("displaying products")
       print(data)
       print("exiting ....")
    
    else:
       print("exiting ....")
# to confirm wether to exit or continue after display has been selected
def confirm():
    q=input("select C to continue to cart or X Exit ")
    if q=="X":
        display(data)
        display('Exiting....')
    if q=="c":
        addAnotherData()
    
x = enter_data()
m = add_data(x,data)
display(m)
